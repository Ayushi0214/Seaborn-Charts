# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data = sns.load_dataset("tips")
#print(data)
#cat plot stands for categorical plot
sns.catplot(x = "day", data = data, hue = "sex", kind = "count")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data = sns.load_dataset("tips")
#print(data)
#cat plot stands for categorical plot
sns.catplot(x = "day",y = "tip", data = data, hue = "sex", kind = "violin")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data = sns.load_dataset("tips")
#print(data)
#cat plot stands for categorical plot
sns.catplot(x = "day",y = "tip", data = data, hue = "sex", kind = "bar")
plt.show()
