# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = {"Days":[1,2,3,4,5],
       "NOP":[50,40,60,30,44]}

df = pd.DataFrame(data)
print(df)

sns.lineplot(data= data, x = "Days", y = "NOP")
plt.show()
# Out:
#    Days  NOP
# 0     1   50
# 1     2   40
# 2     3   60
# 3     4   30
# 4     5   44

# %%
data = pd.read_excel("ESD.xlsx")
#print(data)

color = sns.color_palette("GnBu")
sns.lineplot(data = data,x = "Business Unit", y = "Age", hue = "Ethnicity", palette = color )
plt.show()
# Out:
# C:\Users\WsCube Tech\AppData\Local\Temp\ipykernel_17400\3685906780.py:5: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   sns.lineplot(data = data,x = "Business Unit", y = "Age", hue = "Ethnicity", palette = color )
